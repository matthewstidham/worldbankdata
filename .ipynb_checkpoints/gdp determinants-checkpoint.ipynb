# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('pivoted.csv')
british = pd.read_csv('british.csv').dropna()
continent = pd.read_csv('continent.csv')
education = pd.read_csv('education.csv')

# %%
education = education.replace('..',np.nan)
education.head()
# Out:
#    Time Time Code    Country Name Country Code  \
# 0  1993    YR1993     Afghanistan          AFG
# 1  1993    YR1993         Albania          ALB
# 2  1993    YR1993         Algeria          DZA
# 3  1993    YR1993  American Samoa          ASM
# 4  1993    YR1993         Andorra          AND
#
#   Account ownership at a financial institution or with a mobile-money-service provider, primary education or less (% of population ages 15+) [FX.OWN.TOTL.PL.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Account ownership at a financial institution or with a mobile-money-service provider, secondary education or more (% of population ages 15+) [FX.OWN.TOTL.SO.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Adjusted savings: education expenditure (% of GNI) [NY.ADJ.AEDU.GN.ZS]  \
# 0                                    2.0778859838404
# 1                                                2.8
# 2                                                5.8
# 3                                          11.760709
# 4                                                3.3
#
#   Adjusted savings: education expenditure (current US$) [NY.ADJ.AEDU.CD]  \
# 0                                                NaN
# 1                                       34049997.296
# 2                                     2795394524.966
# 3                                                NaN
# 4                                                NaN
#
#   All education staff compensation, primary (% of total expenditure in primary public institutions) [SE.XPD.MPRM.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   All education staff compensation, secondary (% of total expenditure in secondary public institutions) [SE.XPD.MSEC.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                            ...                                                            \
# 0                                                          ...
# 1                                                          ...
# 2                                                          ...
# 3                                                          ...
# 4                                                          ...
#
#   Trained teachers in upper secondary education, male (% of male teachers) [SE.SEC.TCAQ.UP.MA.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Unemployment with advanced education (% of total labor force with advanced education) [SL.UEM.ADVN.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Unemployment with advanced education, female (% of female labor force with advanced education) [SL.UEM.ADVN.FE.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Unemployment with advanced education, male (% of male labor force with advanced education) [SL.UEM.ADVN.MA.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Unemployment with basic education (% of total labor force with basic education) [SL.UEM.BASC.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Unemployment with basic education, female (% of female labor force with basic education) [SL.UEM.BASC.FE.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Unemployment with basic education, male (% of male labor force with basic education) [SL.UEM.BASC.MA.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Unemployment with intermediate education (% of total labor force with intermediate education) [SL.UEM.INTM.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Unemployment with intermediate education, female (% of female labor force with intermediate education) [SL.UEM.INTM.FE.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Unemployment with intermediate education, male (% of male labor force with intermediate education) [SL.UEM.INTM.MA.ZS]
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 102 columns]

# %%
df = pd.merge(df, education, on=['Time Code','Country Code'])

# %%
df = df.replace('NaN',np.nan)
df.head()
# Out:
#   Time_x Time Code  Country Name_x Country Code  \
# 0   2000    YR2000     Afghanistan          AFG
# 1   2000    YR2000         Albania          ALB
# 2   2000    YR2000         Algeria          DZA
# 3   2000    YR2000  American Samoa          ASM
# 4   2000    YR2000         Andorra          AND
#
#    Population, total [SP.POP.TOTL]  \
# 0                       20093756.0
# 1                        3089027.0
# 2                       31183660.0
# 3                          57521.0
# 4                          65390.0
#
#    Population growth (annual %) [SP.POP.GROW]  \
# 0                                    3.494659
# 1                                   -0.637357
# 2                                    1.349663
# 3                                    1.314208
# 4                                    1.572166
#
#    Surface area (sq. km) [AG.SRF.TOTL.K2]  \
# 0                                652860.0
# 1                                 28750.0
# 2                               2381740.0
# 3                                   200.0
# 4                                   470.0
#
#    Poverty headcount ratio at national poverty lines (% of population) [SI.POV.NAHC]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    GNI, Atlas method (current US$) [NY.GNP.ATLS.CD]  \
# 0                                               NaN
# 1                                      3.599111e+09
# 2                                      4.949310e+10
# 3                                               NaN
# 4                                               NaN
#
#    GNI per capita, Atlas method (current US$) [NY.GNP.PCAP.CD]  \
# 0                                                NaN
# 1                                             1170.0
# 2                                             1590.0
# 3                                                NaN
# 4                                                NaN
#
#                                                             ...                                                            \
# 0                                                           ...
# 1                                                           ...
# 2                                                           ...
# 3                                                           ...
# 4                                                           ...
#
#    Trained teachers in upper secondary education, male (% of male teachers) [SE.SEC.TCAQ.UP.MA.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unemployment with advanced education (% of total labor force with advanced education) [SL.UEM.ADVN.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unemployment with advanced education, female (% of female labor force with advanced education) [SL.UEM.ADVN.FE.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unemployment with advanced education, male (% of male labor force with advanced education) [SL.UEM.ADVN.MA.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unemployment with basic education (% of total labor force with basic education) [SL.UEM.BASC.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unemployment with basic education, female (% of female labor force with basic education) [SL.UEM.BASC.FE.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unemployment with basic education, male (% of male labor force with basic education) [SL.UEM.BASC.MA.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unemployment with intermediate education (% of total labor force with intermediate education) [SL.UEM.INTM.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unemployment with intermediate education, female (% of female labor force with intermediate education) [SL.UEM.INTM.FE.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unemployment with intermediate education, male (% of male labor force with intermediate education) [SL.UEM.INTM.MA.ZS]
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 156 columns]

# %%
from collections import OrderedDict
dd = OrderedDict(sorted(dict(df.isnull().sum()).items(), key=lambda x: x[1]))
print(dd)
# Out:
# OrderedDict([('Time_x', 15), ('Time_y', 15), ('Time Code', 25), ('Country Name_x', 25), ('Country Code', 25), ('Country Name_y', 25), ('Population, total [SP.POP.TOTL]', 31), ('Population growth (annual %) [SP.POP.GROW]', 32), ('Surface area (sq. km) [AG.SRF.TOTL.K2]', 36), ('Primary education, duration (years) [SE.PRM.DURS]', 189), ('Secondary education, duration (years) [SE.SEC.DURS]', 247), ('GDP (current US$) [NY.GDP.MKTP.CD]', 309), ('GDP per capita (current US$) [NY.GDP.PCAP.CD]', 309), ('GDP growth (annual %) [NY.GDP.MKTP.KD.ZG]', 365), ('Inflation, GDP deflator (annual %) [NY.GDP.DEFL.KD.ZG]', 366), ('Foreign direct investment, net inflows (BoP, current US$) [BX.KLT.DINV.CD.WD]', 428), ('Preprimary education, duration (years) [SE.PRE.DURS]', 428), ('Mobile cellular subscriptions (per 100 people) [IT.CEL.SETS.P2]', 456), ('Net barter terms of trade index (2000 = 100) [TT.PRI.MRCH.XD.WD]', 510), ('GNI, Atlas method (current US$) [NY.GNP.ATLS.CD]', 514), ('GNI per capita, Atlas method (current US$) [NY.GNP.PCAP.CD]', 514), ('Fertility rate, total (births per woman) [SP.DYN.TFRT.IN]', 514), ('Merchandise trade (% of GDP) [TG.VAL.TOTL.GD.ZS]', 518), ('Life expectancy at birth, total (years) [SP.DYN.LE00.IN]', 532), ('Forest area (sq. km) [AG.LND.FRST.K2]', 566), ('GNI, PPP (current international $) [NY.GNP.MKTP.PP.CD]', 570), ('GNI per capita, PPP (current international $) [NY.GNP.PCAP.PP.CD]', 570), ('Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]', 599), ('Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS]', 599), ('Adjusted savings: education expenditure (% of GNI) [NY.ADJ.AEDU.GN.ZS]', 599), ('Industry (including construction), value added (% of GDP) [NV.IND.TOTL.ZS]', 610), ('Agriculture, forestry, and fishing, value added (% of GDP) [NV.AGR.TOTL.ZS]', 629), ('Adolescent fertility rate (births per 1,000 women ages 15-19) [SP.ADO.TFRT]', 633), ('Mortality rate, under-5 (per 1,000 live births) [SH.DYN.MORT]', 650), ('Immunization, measles (% of children ages 12-23 months) [SH.IMM.MEAS]', 686), ('Oil rents (% of GDP) [NY.GDP.PETR.RT.ZS]', 696), ('Compulsory education, duration (years) [SE.COM.DURS]', 816), ('Adjusted savings: education expenditure (current US$) [NY.ADJ.AEDU.CD]', 825), ('Gross capital formation (% of GDP) [NE.GDI.TOTL.ZS]', 864), ('Foreign direct investment, net (BoP, current US$) [BN.KLT.DINV.CD]', 895), ('CO2 emissions (metric tons per capita) [EN.ATM.CO2E.PC]', 901), ('Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]', 912), ('Personal remittances, paid (current US$) [BM.TRF.PWKR.CD.DT]', 977), ('Primary education, pupils [SE.PRM.ENRL]', 1028), ('Primary education, pupils (% female) [SE.PRM.ENRL.FE.ZS]', 1049), ('Military expenditure (% of GDP) [MS.MIL.XPND.GD.ZS]', 1205), ('Secondary education, general pupils [SE.SEC.ENRL.GC]', 1214), ('Secondary education, general pupils (% female) [SE.SEC.ENRL.GC.FE.ZS]', 1242), ('Start-up procedures to register a business (number) [IC.REG.PROC]', 1353), ('High-technology exports (% of manufactured exports) [TX.VAL.TECH.MF.ZS]', 1379), ('Secondary education, pupils [SE.SEC.ENRL]', 1428), ('Secondary education, pupils (% female) [SE.SEC.ENRL.FE.ZS]', 1478), ('Net ODA received per capita (current US$) [DT.ODA.ODAT.PC.ZS]', 1509), ('Gross intake ratio in first grade of primary education, total (% of relevant age group) [SE.PRM.GINT.ZS]', 1518), ('School enrollment, secondary (% gross) [SE.SEC.ENRR]', 1526), ('Primary education, teachers [SE.PRM.TCHR]', 1542), ('Gross intake ratio in first grade of primary education, female (% of relevant age group) [SE.PRM.GINT.FE.ZS]', 1580), ('Gross intake ratio in first grade of primary education, male (% of relevant age group) [SE.PRM.GINT.MA.ZS]', 1580), ('Primary education, teachers (% female) [SE.PRM.TCHR.FE.ZS]', 1642), ('School enrollment, primary and secondary (gross), gender parity index (GPI) [SE.ENR.PRSC.FM.ZS]', 1651), ('Energy use (kg of oil equivalent per capita) [EG.USE.PCAP.KG.OE]', 1673), ('Pr ...

# %%
d = dict(df.isnull().sum())
targets = [*{key: d[key] for key in d if d[key] < 700}]

# %%
len(targets)
# Out:
# 36

# %%
filtered = df[targets].dropna()

# %%
filtered.shape
# Out:
# (2533, 36)

# %%
dd = OrderedDict(sorted(dict(education.isnull().sum()).items(), key=lambda x: x[1]))
print(dd)

# %%
british.head()

# %%
continent.head()

# %%
set(british['Current country'])

# %%
crown = df[df['Country Name'].isin(british['Current country'])]

# %%
continent.head()

# %%
filtered.head()

# %%
filtered.dropna()['Country Code'].value_counts()

# %%
y = filtered['GDP (current US$) [NY.GDP.MKTP.CD]']
X = filtered.drop(['GDP (current US$) [NY.GDP.MKTP.CD]','Time','Time Code','Country Name','Country Code','GNI, Atlas method (current US$) [NY.GNP.ATLS.CD]','GNI, PPP (current international $) [NY.GNP.MKTP.PP.CD]'], 1)
rf = RandomForestRegressor()
rf.fit(X, y)
names = X.dtypes.index
print("Features sorted by their score:")
print(sorted(zip(map(lambda x: round(x, 4), rf.feature_importances_), names), reverse=True))

# %%
filtered[filtered['Country Code'] == 'CAN']

# %%
min(filtered['GDP (current US$) [NY.GDP.MKTP.CD]'])

# %%
[*filtered.columns]

# %%
y = filtered['GDP per capita (current US$) [NY.GDP.PCAP.CD]']
X = filtered.drop(['GDP per capita (current US$) [NY.GDP.PCAP.CD]','GDP (current US$) [NY.GDP.MKTP.CD]','Time','Time Code','Country Name','Country Code','GNI, Atlas method (current US$) [NY.GNP.ATLS.CD]','GNI, PPP (current international $) [NY.GNP.MKTP.PP.CD]','GNI per capita, Atlas method (current US$) [NY.GNP.PCAP.CD]','GNI per capita, PPP (current international $) [NY.GNP.PCAP.PP.CD]'], 1)
rf = RandomForestRegressor()
rf.fit(X, y)
names = X.dtypes.index
print("Features sorted by their score:")
print(sorted(zip(map(lambda x: round(x, 4), rf.feature_importances_), names), reverse=True))

# %%
def regression(y, X):
    import statsmodels.api as sm
    import matplotlib.pyplot as plt
    from sklearn.metrics import mean_squared_error
    X = X
    y = y
    model = sm.OLS(y, X)
    model = model.fit()
    predictions = model.predict(X)

    # Plot the model
    plt.figure(figsize=(8,6))
    plt.scatter(predictions, y, s=30, c='r', marker='+', zorder=10)
    plt.xlabel("Predicted Values - $\hat{y}$")
    plt.ylabel("Actual Values - $y$")
    plt.show()
    print("MSE:", mean_squared_error(y, predictions))
    return model.summary()

# %%
regression(y,X)

# %%
x = filtered['Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]']
plt.scatter(x, y, alpha=0.5)
plt.show()
