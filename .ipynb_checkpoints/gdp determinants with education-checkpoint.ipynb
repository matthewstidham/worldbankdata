# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('pivoted.csv')
british = pd.read_csv('british.csv').dropna()
continent = pd.read_csv('continent.csv')

# %%
df = df.replace('NaN',np.nan)
df.head()
# Out:
#    Time Time Code    Country Name Country Code  \
# 0  2000    YR2000     Afghanistan          AFG
# 1  2000    YR2000         Albania          ALB
# 2  2000    YR2000         Algeria          DZA
# 3  2000    YR2000  American Samoa          ASM
# 4  2000    YR2000         Andorra          AND
#
#    Population, total [SP.POP.TOTL]  \
# 0                       20093756.0
# 1                        3089027.0
# 2                       31183660.0
# 3                          57521.0
# 4                          65390.0
#
#    Population growth (annual %) [SP.POP.GROW]  \
# 0                                    3.494659
# 1                                   -0.637357
# 2                                    1.349663
# 3                                    1.314208
# 4                                    1.572166
#
#    Surface area (sq. km) [AG.SRF.TOTL.K2]  \
# 0                                652860.0
# 1                                 28750.0
# 2                               2381740.0
# 3                                   200.0
# 4                                   470.0
#
#    Poverty headcount ratio at national poverty lines (% of population) [SI.POV.NAHC]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    GNI, Atlas method (current US$) [NY.GNP.ATLS.CD]  \
# 0                                               NaN
# 1                                      3.599111e+09
# 2                                      4.949310e+10
# 3                                               NaN
# 4                                               NaN
#
#    GNI per capita, Atlas method (current US$) [NY.GNP.PCAP.CD]  \
# 0                                                NaN
# 1                                             1170.0
# 2                                             1590.0
# 3                                                NaN
# 4                                                NaN
#
#                      ...                     \
# 0                    ...
# 1                    ...
# 2                    ...
# 3                    ...
# 4                    ...
#
#    External debt stocks, total (DOD, current US$) [DT.DOD.DECT.CD]  \
# 0                                       0.000000e+00
# 1                                       1.122377e+09
# 2                                       2.547693e+10
# 3                                                NaN
# 4                                                NaN
#
#    Total debt service (% of GNI) [DT.TDS.DECT.GN.ZS]  \
# 0                                                NaN
# 1                                           0.802873
# 2                                           8.594454
# 3                                                NaN
# 4                                                NaN
#
#    Net migration [SM.POP.NETM]  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#    Personal remittances, paid (current US$) [BM.TRF.PWKR.CD.DT]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Foreign direct investment, net inflows (BoP, current US$) [BX.KLT.DINV.CD.WD]  \
# 0                                           170000.0
# 1                                        143000000.0
# 2                                        280100000.0
# 3                                                NaN
# 4                                                NaN
#
#    Net ODA received per capita (current US$) [DT.ODA.ODAT.PC.ZS]  \
# 0                                           6.768769
# 1                                         102.896478
# 2                                           6.412333
# 3                                                NaN
# 4                                                NaN
#
#    GDP per capita (current US$) [NY.GDP.PCAP.CD]  \
# 0                                            NaN
# 1                                    1175.788981
# 2                                    1757.017797
# 3                                            NaN
# 4                                   21936.530101
#
#    Foreign direct investment, net (BoP, current US$) [BN.KLT.DINV.CD]  \
# 0                                                NaN
# 1                                       -143000000.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]  \
# 0                                                NaN
# 1                                           0.050018
# 2                                           0.339163
# 3                                                NaN
# 4                                                NaN
#
#    Oil rents (% of GDP) [NY.GDP.PETR.RT.ZS]
# 0                                       NaN
# 1                                  0.919240
# 2                                 12.902006
# 3                                       NaN
# 4                                       NaN
#
# [5 rows x 56 columns]

# %%
from collections import OrderedDict
dd = OrderedDict(sorted(dict(df.isnull().sum()).items(), key=lambda x: x[1]))
print(dd)
# Out:
# OrderedDict([('Time', 3), ('Time Code', 5), ('Country Name', 5), ('Country Code', 5), ('Population, total [SP.POP.TOTL]', 11), ('Population growth (annual %) [SP.POP.GROW]', 12), ('Surface area (sq. km) [AG.SRF.TOTL.K2]', 16), ('GDP (current US$) [NY.GDP.MKTP.CD]', 289), ('GDP per capita (current US$) [NY.GDP.PCAP.CD]', 289), ('GDP growth (annual %) [NY.GDP.MKTP.KD.ZG]', 345), ('Inflation, GDP deflator (annual %) [NY.GDP.DEFL.KD.ZG]', 346), ('Foreign direct investment, net inflows (BoP, current US$) [BX.KLT.DINV.CD.WD]', 408), ('Mobile cellular subscriptions (per 100 people) [IT.CEL.SETS.P2]', 436), ('Net barter terms of trade index (2000 = 100) [TT.PRI.MRCH.XD.WD]', 490), ('GNI, Atlas method (current US$) [NY.GNP.ATLS.CD]', 494), ('GNI per capita, Atlas method (current US$) [NY.GNP.PCAP.CD]', 494), ('Fertility rate, total (births per woman) [SP.DYN.TFRT.IN]', 494), ('Merchandise trade (% of GDP) [TG.VAL.TOTL.GD.ZS]', 498), ('Life expectancy at birth, total (years) [SP.DYN.LE00.IN]', 512), ('Forest area (sq. km) [AG.LND.FRST.K2]', 546), ('GNI, PPP (current international $) [NY.GNP.MKTP.PP.CD]', 550), ('GNI per capita, PPP (current international $) [NY.GNP.PCAP.PP.CD]', 550), ('Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]', 579), ('Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS]', 579), ('Industry (including construction), value added (% of GDP) [NV.IND.TOTL.ZS]', 590), ('Agriculture, forestry, and fishing, value added (% of GDP) [NV.AGR.TOTL.ZS]', 609), ('Adolescent fertility rate (births per 1,000 women ages 15-19) [SP.ADO.TFRT]', 613), ('Mortality rate, under-5 (per 1,000 live births) [SH.DYN.MORT]', 630), ('Immunization, measles (% of children ages 12-23 months) [SH.IMM.MEAS]', 666), ('Oil rents (% of GDP) [NY.GDP.PETR.RT.ZS]', 676), ('Gross capital formation (% of GDP) [NE.GDI.TOTL.ZS]', 844), ('Foreign direct investment, net (BoP, current US$) [BN.KLT.DINV.CD]', 875), ('CO2 emissions (metric tons per capita) [EN.ATM.CO2E.PC]', 881), ('Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]', 892), ('Personal remittances, paid (current US$) [BM.TRF.PWKR.CD.DT]', 957), ('Military expenditure (% of GDP) [MS.MIL.XPND.GD.ZS]', 1185), ('Start-up procedures to register a business (number) [IC.REG.PROC]', 1333), ('High-technology exports (% of manufactured exports) [TX.VAL.TECH.MF.ZS]', 1359), ('Net ODA received per capita (current US$) [DT.ODA.ODAT.PC.ZS]', 1489), ('School enrollment, secondary (% gross) [SE.SEC.ENRR]', 1506), ('School enrollment, primary and secondary (gross), gender parity index (GPI) [SE.ENR.PRSC.FM.ZS]', 1631), ('Energy use (kg of oil equivalent per capita) [EG.USE.PCAP.KG.OE]', 1653), ('Prevalence of HIV, total (% of population ages 15-49) [SH.DYN.AIDS.ZS]', 1677), ('Primary completion rate, total (% of relevant age group) [SE.PRM.CMPT.ZS]', 1762), ('Revenue, excluding grants (% of GDP) [GC.REV.XGRT.GD.ZS]', 1774), ('Electric power consumption (kWh per capita) [EG.USE.ELEC.KH.PC]', 1801), ('External debt stocks, total (DOD, current US$) [DT.DOD.DECT.CD]', 1820), ('Total debt service (% of GNI) [DT.TDS.DECT.GN.ZS]', 1870), ('Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]', 2328), ('Market capitalization of listed domestic companies (% of GDP) [CM.MKT.LCAP.GD.ZS]', 2681), ('Income share held by lowest 20% [SI.DST.FRST.20]', 2845), ('Net migration [SM.POP.NETM]', 3135), ('Poverty headcount ratio at national poverty lines (% of population) [SI.POV.NAHC]', 3172), ('Contraceptive prevalence, any methods (% of women ages 15-49) [SP.DYN.CONU.ZS]', 3236), ('Prevalence of underweight, weight for age (% of children under 5) [SH.STA.MALN.ZS]', 3387), ('Water productivity, total (constant 2010 US$ GDP per cubic meter of total freshwater withdrawal) [ER.GDP.FWTL.M3.KD]', 3571)])

# %%
d = dict(df.isnull().sum())
targets = [*{key: d[key] for key in d if d[key] < 700}]

# %%
filtered = df[targets].dropna()

# %%
filtered.shape
# Out:
# (2566, 30)

# %%
british.head()
# Out:
#            Name of colony  Current country  from    to   \
# 0                    Aden     Saudi Arabia   1937  1967
# 1                 Bahamas          Bahamas   1718  1973
# 2              Basutoland          Lesotho   1884  1964
# 3                 Bermuda   United Kingdom   1684  1981
# 4    British Bechuanaland         Botswana   1885  1895
#
#                         Reason for change of status
# 0    Became part of the Federation of South Arabia.
# 1         Became an independent Commonwealth Realm.
# 2  Became British protectorate in 1964; then beca...
# 3       Became British Dependent Territory in 1981.
# 4       Became part of British Cape Colony in 1895.

# %%
continent.head()
# Out:
#    CC a-2  a-3     #                                          Name
# 0  AS  AF  AFG   4.0              Afghanistan, Islamic Republic of
# 1  EU  AL  ALB   8.0                          Albania, Republic of
# 2  AN  AQ  ATA  10.0  Antarctica (the territory South of 60 deg S)
# 3  AF  DZ  DZA  12.0      Algeria, People's Democratic Republic of
# 4  OC  AS  ASM  16.0                                American Samoa

# %%
set(british['Current country'])
# Out:
# {'Australia',
#  'Bahamas',
#  'Belize',
#  'Botswana',
#  'Burma',
#  'Canada',
#  'Cyprus',
#  'Gambia',
#  'Ghana',
#  'Guyana',
#  'Hong Kong',
#  'India',
#  'Jamaica',
#  'Kenya',
#  'Lesotho',
#  'Malaysia',
#  'Malta',
#  'Mauritius',
#  'New Zealand',
#  'Nigeria',
#  'Saudi Arabia',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'South Africa',
#  'Sri Lanka',
#  'St. Kitts and Nevis',
#  'United Kingdom',
#  'United States',
#  'Zimbabwe'}

# %%
crown = df[df['Country Name'].isin(british['Current country'])]

# %%
continent.head()
# Out:
#    CC a-2  a-3     #                                          Name
# 0  AS  AF  AFG   4.0              Afghanistan, Islamic Republic of
# 1  EU  AL  ALB   8.0                          Albania, Republic of
# 2  AN  AQ  ATA  10.0  Antarctica (the territory South of 60 deg S)
# 3  AF  DZ  DZA  12.0      Algeria, People's Democratic Republic of
# 4  OC  AS  ASM  16.0                                American Samoa

# %%
filtered.head()
# Out:
#    Time Time Code         Country Name Country Code  \
# 1  2000    YR2000              Albania          ALB
# 2  2000    YR2000              Algeria          DZA
# 5  2000    YR2000               Angola          AGO
# 6  2000    YR2000  Antigua and Barbuda          ATG
# 7  2000    YR2000            Argentina          ARG
#
#    Population, total [SP.POP.TOTL]  \
# 1                        3089027.0
# 2                       31183660.0
# 5                       16440924.0
# 6                          83584.0
# 7                       37057452.0
#
#    Population growth (annual %) [SP.POP.GROW]  \
# 1                                   -0.637357
# 2                                    1.349663
# 5                                    3.032943
# 6                                    2.119597
# 7                                    1.110875
#
#    Surface area (sq. km) [AG.SRF.TOTL.K2]  \
# 1                                 28750.0
# 2                               2381740.0
# 5                               1246700.0
# 6                                   440.0
# 7                               2780400.0
#
#    GNI, Atlas method (current US$) [NY.GNP.ATLS.CD]  \
# 1                                      3.599111e+09
# 2                                      4.949310e+10
# 5                                      5.903014e+09
# 6                                      7.710861e+08
# 7                                      2.755443e+11
#
#    GNI per capita, Atlas method (current US$) [NY.GNP.PCAP.CD]  \
# 1                                             1170.0
# 2                                             1590.0
# 5                                              360.0
# 6                                             9230.0
# 7                                             7440.0
#
#    GNI, PPP (current international $) [NY.GNP.MKTP.PP.CD]  \
# 1                                       1.281163e+10
# 2                                       2.399026e+11
# 5                                       3.054863e+10
# 6                                       1.185529e+09
# 7                                       4.260279e+11
#
#                      ...                     \
# 1                    ...
# 2                    ...
# 5                    ...
# 6                    ...
# 7                    ...
#
#    Agriculture, forestry, and fishing, value added (% of GDP) [NV.AGR.TOTL.ZS]  \
# 1                                          23.498642
# 2                                           8.395059
# 5                                           5.664690
# 6                                           1.589540
# 7                                           4.679917
#
#    Industry (including construction), value added (% of GDP) [NV.IND.TOTL.ZS]  \
# 1                                          14.818675
# 2                                          54.371478
# 5                                          72.122955
# 6                                          13.827114
# 7                                          25.990948
#
#    Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]  \
# 1                                          17.867084
# 2                                          42.069718
# 5                                          89.685831
# 6                                          56.237667
# 7                                          10.986396
#
#    Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS]  \
# 1                                          38.053345
# 2                                          20.788626
# 5                                          62.861278
# 6                                          60.044123
# 7                                          11.636106
#
#    Mobile cellular subscriptions (per 100 people) [IT.CEL.SETS.P2]  \
# 1                                           0.954237
# 2                                           0.275785
# 5                                           0.156962
# 6                                          26.320827
# 7                                          17.507815
#
#    Merchandise trade (% of GDP) [TG.VAL.TOTL.GD.ZS]  \
# 1                                         37.112161
# 2                                         56.948093
# 5                                        120.060093
# 6                                         55.290628
# 7                                         18.119043
#
#    Net barter terms of trade index (2000 = 100) [TT.PRI.MRCH.XD.WD]  \
# 1                                              100.0
# 2                                              100.0
# 5                                              100.0
# 6                                              100.0
# 7                                              100.0
#
#    Foreign direct investment, net inflows (BoP, current US$) [BX.KLT.DINV.CD.WD]  \
# 1                                       1.430000e+08
# 2                                       2.801000e+08
# 5                                       8.786200e+08
# 6                                       4.311593e+07
# 7                                       1.041831e+10
#
#    GDP per capita (current US$) [NY.GDP.PCAP.CD]  \
# 1                                    1175.788981
# 2                                    1757.017797
# 5                                     555.296942
# 6                                    9932.029788
# 7                                    7669.273916
#
#    Oil rents (% of GDP) [NY.GDP.PETR.RT.ZS]
# 1                                  0.919240
# 2                                 12.902006
# 5                                 59.685139
# 6                                  0.000000
# 7                                  1.794962
#
# [5 rows x 30 columns]

# %%
filtered.dropna()['Country Code'].value_counts()
# Out:
# COM    16
# BLR    16
# ARG    16
# RWA    16
# ROU    16
# AUT    16
# CHL    16
# GMB    16
# BHS    16
# ISR    16
# SEN    16
# PER    16
# UKR    16
# POL    16
# SUR    16
# LBN    16
# FJI    16
# CMR    16
# ATG    16
# GRD    16
# SAU    16
# TGO    16
# TUN    16
# HND    16
# COD    16
# MRT    16
# MYS    16
# ZAF    16
# BRB    16
# DOM    16
#        ..
# SYC    15
# VEN    15
# VUT    15
# GIN    15
# KIR    14
# MMR    14
# BEL    14
# BDI    14
# BTN    14
# LUX    14
# TKM    13
# SLE    13
# WSM    13
# AFG    12
# QAT    12
# ZWE    12
# SDN    12
# IRQ    10
# MDV    10
# ERI    10
# GNQ    10
# LSO     9
# BHR     9
# SRB     8
# CAN     8
# LBY     7
# KWT     6
# ETH     5
# PNG     5
# AGO     2
# Name: Country Code, Length: 170, dtype: int64

# %%
y = filtered['GDP (current US$) [NY.GDP.MKTP.CD]']
X = filtered.drop(['GDP (current US$) [NY.GDP.MKTP.CD]','Time','Time Code','Country Name','Country Code','GNI, Atlas method (current US$) [NY.GNP.ATLS.CD]','GNI, PPP (current international $) [NY.GNP.MKTP.PP.CD]'], 1)
rf = RandomForestRegressor()
rf.fit(X, y)
names = X.dtypes.index
print("Features sorted by their score:")
print(sorted(zip(map(lambda x: round(x, 4), rf.feature_importances_), names), reverse=True))
# Out:
# Features sorted by their score:
# [(0.45440000000000003, 'Foreign direct investment, net inflows (BoP, current US$) [BX.KLT.DINV.CD.WD]'), (0.15540000000000001, 'Population, total [SP.POP.TOTL]'), (0.11360000000000001, 'Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]'), (0.088700000000000001, 'Forest area (sq. km) [AG.LND.FRST.K2]'), (0.044499999999999998, 'GNI per capita, Atlas method (current US$) [NY.GNP.PCAP.CD]'), (0.031899999999999998, 'GDP per capita (current US$) [NY.GDP.PCAP.CD]'), (0.0207, 'Mobile cellular subscriptions (per 100 people) [IT.CEL.SETS.P2]'), (0.018100000000000002, 'Life expectancy at birth, total (years) [SP.DYN.LE00.IN]'), (0.0129, 'Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS]'), (0.01, 'Mortality rate, under-5 (per 1,000 live births) [SH.DYN.MORT]'), (0.0092999999999999992, 'Net barter terms of trade index (2000 = 100) [TT.PRI.MRCH.XD.WD]'), (0.0077999999999999996, 'Agriculture, forestry, and fishing, value added (% of GDP) [NV.AGR.TOTL.ZS]'), (0.0076, 'Adolescent fertility rate (births per 1,000 women ages 15-19) [SP.ADO.TFRT]'), (0.0055999999999999999, 'GNI per capita, PPP (current international $) [NY.GNP.PCAP.PP.CD]'), (0.0051000000000000004, 'Oil rents (% of GDP) [NY.GDP.PETR.RT.ZS]'), (0.0038, 'Population growth (annual %) [SP.POP.GROW]'), (0.0030999999999999999, 'Merchandise trade (% of GDP) [TG.VAL.TOTL.GD.ZS]'), (0.0030000000000000001, 'Immunization, measles (% of children ages 12-23 months) [SH.IMM.MEAS]'), (0.0014, 'Surface area (sq. km) [AG.SRF.TOTL.K2]'), (0.0012999999999999999, 'Industry (including construction), value added (% of GDP) [NV.IND.TOTL.ZS]'), (0.00089999999999999998, 'Fertility rate, total (births per woman) [SP.DYN.TFRT.IN]'), (0.00069999999999999999, 'Inflation, GDP deflator (annual %) [NY.GDP.DEFL.KD.ZG]'), (0.00029999999999999997, 'GDP growth (annual %) [NY.GDP.MKTP.KD.ZG]')]

# %%
filtered[filtered['Country Code'] == 'CAN']
# Out:
#       Time Time Code Country Name Country Code  \
# 1554  2007    YR2007       Canada          CAN
# 1771  2008    YR2008       Canada          CAN
# 1988  2009    YR2009       Canada          CAN
# 2205  2010    YR2010       Canada          CAN
# 2422  2011    YR2011       Canada          CAN
# 2639  2012    YR2012       Canada          CAN
# 2856  2013    YR2013       Canada          CAN
# 3073  2014    YR2014       Canada          CAN
#
#       Population, total [SP.POP.TOTL]  \
# 1554                       32887928.0
# 1771                       33245773.0
# 1988                       33628571.0
# 2205                       34005274.0
# 2422                       34342780.0
# 2639                       34750545.0
# 2856                       35152370.0
# 3073                       35535348.0
#
#       Population growth (annual %) [SP.POP.GROW]  \
# 1554                                    0.969854
# 1771                                    1.082197
# 1988                                    1.144840
# 2205                                    1.113960
# 2422                                    0.987618
# 2639                                    1.180345
# 2856                                    1.149679
# 3073                                    1.083588
#
#       Surface area (sq. km) [AG.SRF.TOTL.K2]  \
# 1554                               9984670.0
# 1771                               9984670.0
# 1988                               9984670.0
# 2205                               9984670.0
# 2422                               9984670.0
# 2639                               9984670.0
# 2856                               9984670.0
# 3073                               9984670.0
#
#       GNI, Atlas method (current US$) [NY.GNP.ATLS.CD]  \
# 1554                                      1.362354e+12
# 1771                                      1.489867e+12
# 1988                                      1.449749e+12
# 2205                                      1.508743e+12
# 2422                                      1.616214e+12
# 2639                                      1.768641e+12
# 2856                                      1.849763e+12
# 3073                                      1.845393e+12
#
#       GNI per capita, Atlas method (current US$) [NY.GNP.PCAP.CD]  \
# 1554                                            41420.0
# 1771                                            44810.0
# 1988                                            43110.0
# 2205                                            44370.0
# 2422                                            47060.0
# 2639                                            50900.0
# 2856                                            52620.0
# 3073                                            51930.0
#
#       GNI, PPP (current international $) [NY.GNP.MKTP.PP.CD]  \
# 1554                                       1.278020e+12
# 1771                                       1.319337e+12
# 1988                                       1.281970e+12
# 2205                                       1.334171e+12
# 2422                                       1.400441e+12
# 2639                                       1.438515e+12
# 2856                                       1.526600e+12
# 3073                                       1.591364e+12
#
#                         ...                     \
# 1554                    ...
# 1771                    ...
# 1988                    ...
# 2205                    ...
# 2422                    ...
# 2639                    ...
# 2856                    ...
# 3073                    ...
#
#       Agriculture, forestry, and fishing, value added (% of GDP) [NV.AGR.TOTL.ZS]  \
# 1554                                           1.407026
# 1771                                           1.597655
# 1988                                           1.375940
# 2205                                           1.331664
# 2422                                           1.605664
# 2639                                           1.647294
# 2856                                           1.725294
# 3073                                           1.424796
#
#       Industry (including construction), value added (% of GDP) [NV.IND.TOTL.ZS]  \
# 1554                                          29.075354
# 1771                                          29.720017
# 1988                                          25.445636
# 2205                                          26.713117
# 2422                                          27.521269
# 2639                                          27.033566
# 2856                                          27.016409
# 3073                                          27.533238
#
#       Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]  \
# 1554                                          34.153166
# 1771                                          34.323135
# 1988                                          28.435750
# 2205                                          29.071956
# 2422                                          30.564624
# 2639                                          30.213605
# 2856                                          30.163338
# 3073                                          31.536896
#
#       Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS]  \
# 1554                                          32.038878
# 1771                                          32.601095
# 1988                                          29.912496
# 2205                                          30.988773
# 2422                                          31.763999
# 2639                                          32.183532
# 2856                                          31.810056
# 3073                                          32.520727
#
#       Mobile cellular subscriptions (per 100 people) [IT.CEL.SETS.P2]  \
# 1554                                          61.409575
# 1771                                          66.136204
# 1988                                          70.470610
# 2205                                          75.582109
# 2422                                          77.710107
# 2639                                          79.425330
# 2856                                          80.441361
# 3073                                          80.857239
#
#       Merchandise trade (% of GDP) [TG.VAL.TOTL.GD.ZS]  \
# 1554                                         55.351142
# 1771                                         56.514356
# 1988                                         47.113680
# 2205                                         48.973575
# 2422                                         51.154541
# 2639                                         51.082255
# 2856                                         50.693616
# 3073                                         52.834351
#
#       Net barter terms of trade index (2000 = 100) [TT.PRI.MRCH.XD.WD]  \
# 1554                                         118.515583
# 1771                                         125.015297
# 1988                                         108.862551
# 2205                                         117.825700
# 2422                                         120.494223
# 2639                                         117.169403
# 2856                                         119.109281
# 3073                                         118.749088
#
#       Foreign direct investment, net inflows (BoP, current US$) [BX.KLT.DINV.CD.WD]  \
# 1554                                       1.204231e+11
# 1771                                       7.011695e+10
# 1988                                       2.093140e+10
# 2205                                       2.971290e+10
# 2422                                       3.831806e+10
# 2639                                       4.937781e+10
# 2856                                       6.704760e+10
# 3073                                       6.410001e+10
#
#       GDP per capita (current US$) [NY.GDP.PCAP.CD]  \
# 1554                                   44544.526800
# 1771                                   46596.335991
# 1988                                   40773.454364
# 2205                                   47447.476024
# 2422                                   52082.210760
# 2639                                   52496.694870
# 2856                                   52418.315062
# 3073                                   50633.208822
#
#       Oil rents (% of GDP) [NY.GDP.PETR.RT.ZS]
# 1554                                  1.617791
# 1771                                  2.669144
# 1988                                  1.383318
# 2205                                  1.625590
# 2422                                  1.967510
# 2639                                  1.438580
# 2856                                  1.640555
# 3073                                  1.426126
#
# [8 rows x 30 columns]

# %%
min(filtered['GDP (current US$) [NY.GDP.MKTP.CD]'])
# Out:
# 63101272.3699183

# %%
[*filtered.columns]
# Out:
# ['Time',
#  'Time Code',
#  'Country Name',
#  'Country Code',
#  'Population, total [SP.POP.TOTL]',
#  'Population growth (annual %) [SP.POP.GROW]',
#  'Surface area (sq. km) [AG.SRF.TOTL.K2]',
#  'GNI, Atlas method (current US$) [NY.GNP.ATLS.CD]',
#  'GNI per capita, Atlas method (current US$) [NY.GNP.PCAP.CD]',
#  'GNI, PPP (current international $) [NY.GNP.MKTP.PP.CD]',
#  'GNI per capita, PPP (current international $) [NY.GNP.PCAP.PP.CD]',
#  'Life expectancy at birth, total (years) [SP.DYN.LE00.IN]',
#  'Fertility rate, total (births per woman) [SP.DYN.TFRT.IN]',
#  'Adolescent fertility rate (births per 1,000 women ages 15-19) [SP.ADO.TFRT]',
#  'Mortality rate, under-5 (per 1,000 live births) [SH.DYN.MORT]',
#  'Immunization, measles (% of children ages 12-23 months) [SH.IMM.MEAS]',
#  'Forest area (sq. km) [AG.LND.FRST.K2]',
#  'GDP (current US$) [NY.GDP.MKTP.CD]',
#  'GDP growth (annual %) [NY.GDP.MKTP.KD.ZG]',
#  'Inflation, GDP deflator (annual %) [NY.GDP.DEFL.KD.ZG]',
#  'Agriculture, forestry, and fishing, value added (% of GDP) [NV.AGR.TOTL.ZS]',
#  'Industry (including construction), value added (% of GDP) [NV.IND.TOTL.ZS]',
#  'Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]',
#  'Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS]',
#  'Mobile cellular subscriptions (per 100 people) [IT.CEL.SETS.P2]',
#  'Merchandise trade (% of GDP) [TG.VAL.TOTL.GD.ZS]',
#  'Net barter terms of trade index (2000 = 100) [TT.PRI.MRCH.XD.WD]',
#  'Foreign direct investment, net inflows (BoP, current US$) [BX.KLT.DINV.CD.WD]',
#  'GDP per capita (current US$) [NY.GDP.PCAP.CD]',
#  'Oil rents (% of GDP) [NY.GDP.PETR.RT.ZS]']

# %%
y = filtered['GDP per capita (current US$) [NY.GDP.PCAP.CD]']
X = filtered.drop(['GDP per capita (current US$) [NY.GDP.PCAP.CD]','GDP (current US$) [NY.GDP.MKTP.CD]','Time','Time Code','Country Name','Country Code','GNI, Atlas method (current US$) [NY.GNP.ATLS.CD]','GNI, PPP (current international $) [NY.GNP.MKTP.PP.CD]','GNI per capita, Atlas method (current US$) [NY.GNP.PCAP.CD]','GNI per capita, PPP (current international $) [NY.GNP.PCAP.PP.CD]'], 1)
rf = RandomForestRegressor()
rf.fit(X, y)
names = X.dtypes.index
print("Features sorted by their score:")
print(sorted(zip(map(lambda x: round(x, 4), rf.feature_importances_), names), reverse=True))
# Out:
# Features sorted by their score:
# [(0.42049999999999998, 'Agriculture, forestry, and fishing, value added (% of GDP) [NV.AGR.TOTL.ZS]'), (0.36720000000000003, 'Life expectancy at birth, total (years) [SP.DYN.LE00.IN]'), (0.042299999999999997, 'Industry (including construction), value added (% of GDP) [NV.IND.TOTL.ZS]'), (0.041099999999999998, 'Mortality rate, under-5 (per 1,000 live births) [SH.DYN.MORT]'), (0.019699999999999999, 'Fertility rate, total (births per woman) [SP.DYN.TFRT.IN]'), (0.016799999999999999, 'Adolescent fertility rate (births per 1,000 women ages 15-19) [SP.ADO.TFRT]'), (0.016199999999999999, 'Net barter terms of trade index (2000 = 100) [TT.PRI.MRCH.XD.WD]'), (0.0134, 'Mobile cellular subscriptions (per 100 people) [IT.CEL.SETS.P2]'), (0.0104, 'Surface area (sq. km) [AG.SRF.TOTL.K2]'), (0.0094999999999999998, 'Population, total [SP.POP.TOTL]'), (0.0068999999999999999, 'Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS]'), (0.0064999999999999997, 'Population growth (annual %) [SP.POP.GROW]'), (0.0064000000000000003, 'Oil rents (% of GDP) [NY.GDP.PETR.RT.ZS]'), (0.0058999999999999999, 'Forest area (sq. km) [AG.LND.FRST.K2]'), (0.0041999999999999997, 'Inflation, GDP deflator (annual %) [NY.GDP.DEFL.KD.ZG]'), (0.0032000000000000002, 'Merchandise trade (% of GDP) [TG.VAL.TOTL.GD.ZS]'), (0.0028999999999999998, 'Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]'), (0.0028, 'Foreign direct investment, net inflows (BoP, current US$) [BX.KLT.DINV.CD.WD]'), (0.0020999999999999999, 'Immunization, measles (% of children ages 12-23 months) [SH.IMM.MEAS]'), (0.002, 'GDP growth (annual %) [NY.GDP.MKTP.KD.ZG]')]

# %%
def regression(y, X):
    import statsmodels.api as sm
    import matplotlib.pyplot as plt
    from sklearn.metrics import mean_squared_error
    X = X
    y = y
    model = sm.OLS(y, X)
    model = model.fit()
    predictions = model.predict(X)

    # Plot the model
    plt.figure(figsize=(8,6))
    plt.scatter(predictions, y, s=30, c='r', marker='+', zorder=10)
    plt.xlabel("Predicted Values - $\hat{y}$")
    plt.ylabel("Actual Values - $y$")
    plt.show()
    print("MSE:", mean_squared_error(y, predictions))
    return model.summary()

# %%
regression(y,X)
# Out:
# /home/matthew/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# MSE: 112422088.172
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                           OLS Regression Results
# =========================================================================================================
# Dep. Variable:     GDP per capita (current US$) [NY.GDP.PCAP.CD]   R-squared:                       0.736
# Model:                                                       OLS   Adj. R-squared:                  0.734
# Method:                                            Least Squares   F-statistic:                     355.8
# Date:                                           Sat, 08 Sep 2018   Prob (F-statistic):               0.00
# Time:                                                   09:55:19   Log-Likelihood:                -27425.
# No. Observations:                                           2566   AIC:                         5.489e+04
# Df Residuals:                                               2546   BIC:                         5.501e+04
# Df Model:                                                     20
# Covariance Type:                                       nonrobust
# =================================================================================================================================================
#                                                                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------
# Population, total [SP.POP.TOTL]                                               -1.709e-05   1.89e-06     -9.035      0.000   -2.08e-05   -1.34e-05
# Population growth (annual %) [SP.POP.GROW]                                     2454.3603    190.390     12.891      0.000    2081.026    2827.695
# Surface area (sq. km) [AG.SRF.TOTL.K2]                                            0.0005      0.000      1.695      0.090   -8.36e-05       0.001
# Life expectancy at birth, total (years) [SP.DYN.LE00.IN]                        476.9161     26.263     18.160      0.000     425.418     528.414
# Fertility rate, total (births per woman) [SP.DYN.TFRT.IN]                     -1450.7997    374.540     -3.874      0.000   -2185.234    -716.366
# Adolescent fertility rate (births per 1,000 women ages 15-19) [SP.ADO.TFRT]    -119.6184      8.763    -13.651      0.000    -136.801    -102.436
# Mortality rate, under-5 (per 1,000 live births) [SH.DYN.MORT]                   121.4190     13.472      9.012      0.000      95.001     147.837
# Immunization, measles (% of children ages 12-23 months) [SH.IMM.MEAS]          -180.2585     19.551     -9.220      0.000    -218.597    -141.920
# Forest area (sq. km) [AG.LND.FRST.K2]                                            -0.0013      0.001     -1.874      0.061      -0.003    6.01e-05
# GDP growth (annual %) [NY.GDP.MKTP.KD.ZG]                                      -228.7903     51.198     -4.469      0.000    -329.184    -128.397
# Inflation, GDP deflator (annual %) [NY.GDP.DEFL.KD.ZG]                           -4.2635      3.972     -1.073      0.283     -12.053       3.526
# Agriculture, forestry, and fishing, value added (% of GDP) [NV.AGR.TOTL.ZS]    -299.0525     31.535     -9.483      0.000    -360.889    -237.216
# Industry (including construction), value added (% of GDP) [NV.IND.TOTL.ZS]     -224.1974     29.517     -7.595      0.000    -282.078    -166.317
# Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]                       374.4920     17.033     21.987      0.000     341.093     407.891
# Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS]                      -150.5206     17.360     -8.671      0.000    -184.562    -116.479
# Mobile cellular subscriptions (per 100 people) [IT.CEL.SETS.P2]                  58.7128      6.099      9.626      0.000      46.753      70.673
# Merchandise trade (% of GDP) [TG.VAL.TOTL.GD.ZS]                               -135.5617     11.559    -11.728      0.000    -158.227    -112.897
# Net barter terms of trade index (2000 = 100) [TT.PRI.MRCH.XD.WD]                 34.9423      5.528      6.321      0.000      24.103      45.782
# Foreign direct investment, net inflows (BoP, current US$) [BX.KLT.DINV.CD.WD]  1.076e-07   6.64e-09     16.219      0.000    9.46e-08    1.21e-07
# Oil rents (% of GDP) [NY.GDP.PETR.RT.ZS]                                       -136.6045     36.352     -3.758      0.000    -207.887     -65.322
# ==============================================================================
# Omnibus:                      922.086   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6241.883
# Skew:                           1.534   Prob(JB):                         0.00
# Kurtosis:                       9.997   Cond. No.                     7.04e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.04e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
